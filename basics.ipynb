# %% [markdown]
# # Web Scraping com Beatiful Soup

# %% [markdown]
# [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/) é um pacote Python para analisar documentos HTML e XML. Ele cria uma árvore de análise para páginas analisadas que podem ser usadas para extrair dados de HTML, o que é útil para web scraping.

# %%
# Importar a biblioteca do BeautifulSoup
from bs4 import BeautifulSoup

# Ler o arquivo html
with open("Beautiful Soup Documentation.html", "r", encoding="utf-8") as arquivo:
    soup = BeautifulSoup(arquivo, "html.parser")

# print(soup.prettify())

# %%
# Acessar o título da página
titulo = soup.title
print(titulo.text)
# Out:
# Beautiful Soup Documentation — Beautiful Soup 4.12.0 documentation

# %% [markdown]
# #### Usando o método `find()` do pacote BeautifulSoup, podemos encontrar o primeiro elemento com um determinado nome de tag:

# %%
h1 = soup.find("h1")
print(h1.prettify())
# Out:
# <h1>
#  Beautiful Soup Documentation
#  <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#module-bs4" title="Permalink to this heading">
#   ¶
#  </a>
# </h1>

# %%
# Acessar o primeiro link da página
link = soup.find("a")
print(link.prettify())
# Out:
# <a accesskey="I" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/genindex.html" title="General Index">
#  index
# </a>

# %% [markdown]
# #### O método `find_all()` retorna uma lista contendo todos os elementos com um determinado nome de tag, como uma lista Python:

# %%
# Buscar todos os links da página
links = soup.find_all("a")
print(links)
# Out:
# [<a accesskey="I" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/genindex.html" title="General Index">index</a>, <a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/py-modindex.html" title="Python Module Index">modules</a>, <a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#">Beautiful Soup 4.12.0 documentation</a>, <a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/">Beautiful Soup Documentation</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#module-bs4" title="Permalink to this heading">¶</a>, <a class="reference external" href="http://www.crummy.com/software/BeautifulSoup/">Beautiful Soup</a>, <a class="reference external" href="http://www.crummy.com/software/BeautifulSoup/bs3/documentation.html">Beautiful Soup 3</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#porting-code-to-bs4">Porting code to BS4</a>, <a class="reference external" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc.zh/">这篇文档当然还有中文版.</a>, <a class="reference external" href="http://kondou.com/BS4/">外部リンク</a>, <a class="reference external" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc.ko/">이 문서는 한국어 번역도 가능합니다.</a>, <a class="reference external" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc.ptbr">Este documento também está disponível em Português do Brasil.</a>, <a class="reference external" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc.ru/">Эта документация доступна на русском языке.</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#getting-help" title="Permalink to this heading">¶</a>, <a class="reference external" href="https://groups.google.com/forum/?fromgroups#!forum/beautifulsoup">send mail to the discussion group</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#diagnose"><span class="std std-ref">what the diagnose() function says</span></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#quick-start" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-beautiful-soup" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference external" href="http://www.crummy.com/software/BeautifulSoup/bs3/documentation.html">Beautiful Soup 3</a>, <a class="reference external" href="http://www.crummy.com/software/BeautifulSoup/download/4.x/">download the Beautiful Soup 4 source tarball</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-a-parser" title="Permalink to this heading">¶</a>, <a class="reference external" href="http://lxml.de/">lxml parser</a>, <a class="reference external" href="http://code.google.com/p/html5lib/">html5lib parser</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#differences-between-parsers">Differences
# between parsers</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#making-the-soup" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id15">Parsing XML</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kinds-of-objects" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString" title="bs4.NavigableString"><code class="xref py py-class docutils literal notranslate"><span class="pre">NavigableString</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Comment" title="bs4.Comment"><code class="xref py py-class docutils literal notranslate"><span class="pre">Comment</span></code></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="Permalink to this definition">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-the-tree">Navigating the tree</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree">Searching the tree</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag.name" title="Permalink to this definition">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag.attrs" title="Permalink to this definition">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#multi-valued-attributes" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString" title="Permalink to this definition">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString" title="bs4.NavigableString"><code class="xref py py-class docutils literal notranslate"><span class="pre">NavigableString</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString" title="bs4.NavigableString"><code class="xref py py-class docutils literal notranslate"><span class="pre">NavigableString</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-the-tree">Navigating
# the tree</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree">Searching the tree</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString" title="bs4.NavigableString"><code class="xref py py-class docutils literal notranslate"><span class="pre">NavigableString</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#replace-with"><span class="std std-ref">replace_with()</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString" title="bs4.NavigableString"><code class="xref py py-class docutils literal notranslate"><span class="pre">NavigableString</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-the-tree">Navigating the tree</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree">Searching the tree</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString" title="bs4.NavigableString"><code class="xref py py-class docutils literal notranslate"><span class="pre">NavigableString</span></code></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="Permalink to this definition">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-the-tree">Navigating the tree</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree">Searching the tree</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#modifying-the-tree">Modifying the tree</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#special-strings" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString" title="bs4.NavigableString"><code class="xref py py-class docutils literal notranslate"><span class="pre">NavigableString</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/Beautifu ...
# declaration</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.CData" title="Permalink to this definition">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString" title="bs4.NavigableString"><code class="xref py py-class docutils literal notranslate"><span class="pre">NavigableString</span></code></a>, <a class="reference external" href="https://www.w3.org/TR/REC-xml/#sec-cdata-sect">CData section</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.ProcessingInstruction" title="Permalink to this definition">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString" title="bs4.NavigableString"><code class="xref py py-class docutils literal notranslate"><span class="pre">NavigableString</span></code></a>, <a class="reference external" href="https://www.w3.org/TR/REC-xml/#sec-pi">XML processing instruction</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-the-tree" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#going-down" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-using-tag-names" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree">Searching the tree</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#contents-and-children" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#modifying-the-tree">Modifying the tree</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#descendants" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#string" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString" title="bs4.NavigableString"><code class="xref py py-class docutils literal notranslate"><span class="pre">NavigableString</span></code></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#strings-and-stripped-strings" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#going-up" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parent" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"> ...
# string</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-regular-expression">a regular expression</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-list">a list</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-function">a function</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-value-true">the value
# True</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-keyword-arguments" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-string">a string</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-regular-expression">a regular
# expression</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-list">a list</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-function">a function</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-value-true">the value True</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-by-css-class" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#multivalue"><span class="std std-ref">Remember</span></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-string-argument" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-string">a string</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-regular-expression">a
# regular expression</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-list">a list</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-function">a function</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-value-true">the value True</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-limit-argument" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-recursive-argument" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#calling-a-tag-is-like-calling-find-all" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name"><span class="std std-ref">name</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs"><span class="std std-ref">attrs</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#recursive"><span class="std std-ref">recursive</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11"><span class="std std-ref">string</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs"><span class="std std-ref">**kwargs</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-using-tag-names">Navigating using tag
# names</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-parents-and-find-parent" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name"><span class="std std-ref">name</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs"><span class="std std-ref">attrs</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11"><span class="std std-ref">string</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#limit"><span class="std std-ref">limit</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs"><span class="std std-ref">**kwargs</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name"><span class="std std-ref">name</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs"><span class="std std-ref">attrs</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11"><span class="std std-ref">string</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs"><span class="std std-ref">**kwargs</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parent">.parent</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parents">.parents</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-next-siblings-and-find-next-sibling" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name"><span class="std std-ref">name</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs"><span class="std std-ref">attrs</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11"><span class="std std-ref">string</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#limit"><span class="std std-ref">limit</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs"><span class="std std-ref">**kwargs</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name"><span class="std std-ref">name</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs"><span class="std std-ref">attrs</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11"><span class="std std-ref">string</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs"><span class="std std-ref">**kwargs</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#sibling-generators"><span class="std std-ref">.next_siblings</span></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-previous-siblings-and-find-previous-sibling" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name"><span class="std std-ref">name</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs"><span class="std std-ref">attrs</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11"><span class="std std-ref">string</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#limit"><span class="std st ...
# selectors</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#advanced-soup-sieve-features" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference external" href="https://facelessuser.github.io/soupsieve/">the Soup Sieve
# documentation</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#namespaces-in-css-selectors" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#history-of-css-selector-support" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#modifying-the-tree" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#changing-tag-names-and-attributes" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag.attrs" title="bs4.Tag.attrs"><code class="xref py py-attr docutils literal notranslate"><span class="pre">Tag.attrs</span></code></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#modifying-string" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#append" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#extend" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigablestring-and-new-tag" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString" title="bs4.NavigableString"><code class="xref py py-class docutils literal notranslate"><span class="pre">NavigableString</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString" title="bs4.NavigableString"><code class="xref py py-class docutils literal notranslate"><span class="pre">NavigableString</span></code></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#insert" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#insert-before-and-insert-after" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#clear" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#extract" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#decompose" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="reference internal" href="https://www.cr ...
# html5lib.</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parser-installation"><span class="std std-ref">install lxml or html5lib.</span></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#version-mismatch-problems" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parsing-xml" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parser-installation"><span class="std std-ref">have lxml installed</span></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#other-parser-problems" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#differences-between-parsers">Differences between parsers</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference external" href="http://www.w3.org/TR/html5/syntax.html#syntax">HTML tags and attributes are case-insensitive</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parsing-xml"><span class="std std-ref">parse the document as XML.</span></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#miscellaneous" title="Permalink to this heading">¶</a>, <a class="reference external" href="http://wiki.python.org/moin/PrintFails">this page on the
# Python wiki</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#improving-performance" title="Permalink to this heading">¶</a>, <a class="reference external" href="http://lxml.de/">lxml</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parser-installation"><span class="std std-ref">start</span></a>, <a class="reference external" href="http://pypi.python.org/pypi/cchardet/">cchardet</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parsing-only-part-of-a-document">Parsing only part of a document</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#translating-this-documentation" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id16" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference external" href="http://www.crummy.com/software/BeautifulSoup/bs3/download/3.x/BeautifulSoup-3.2.0.tar.gz">download a tarball of Beautiful Soup 3.2.0</a>, <a class="reference external" href="http://www.crummy.com/software/BeautifulSoup/bs3/documentation.html">The documentation for Beautiful Soup 3 is archived online</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#porting-code-to-bs4" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference external" href="http://www.python.org/dev/peps/pep-0008/">PEP 8 compliance</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#you-need-a-parser" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-a-parser">Installing a parser</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#method-names" title="Permalink to this heading">¶</a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#generators" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#string-generators"><span class="std std-ref">.strings and
# .stripped_strings</span></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#xml" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#entities" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#unicode-dammit">Unicode,
# Dammit</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#output-formatters"><span class="std std-ref">output formatter</span></a>, <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id17" title="Permalink to this heading">¶</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#string"><span class="std std-ref">Tag.string</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#multi-valued-attributes">Multi-valued attributes</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag" title="bs4.Tag"><code class="xref py py-class docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11"><span class="std std-ref">string</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name"><span class="std std-ref">name</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#string"><span class="std std-ref">Tag.string</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11"><span class="std std-ref">string</span></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup"><code class="xref py py-class docutils literal notranslate"><span class="pre">BeautifulSoup</span></code></a>, <a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#">Table of Contents</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#">Beautiful Soup Documentation</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#getting-help">Getting help</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#quick-start">Quick Start</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-beautiful-soup">Installing Beautiful Soup</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-a-parser">Installing a parser</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#making-the-soup">Making the soup</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kinds-of-objects">Kinds of objects</a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag"><code class="docutils literal notranslate"><span class="pre">Tag</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag.name"><code class="docutils literal notranslate"><span class="pre">Tag.name</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag.attrs"><code class="docutils literal notranslate"><span class="pre">Tag.attrs</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString"><code class="docutils literal notranslate"><span class="pre">NavigableString</span></code></a>, <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup"><code class="docutils literal no ...

# %%
# Acessar o primeiro link da lista
print(links[0].prettify())
# Out:
# <a accesskey="I" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/genindex.html" title="General Index">
#  index
# </a>

# %%
# Acessar os atributos do link
print(links[0].attrs)
# Out:
# {'href': 'https://www.crummy.com/software/BeautifulSoup/bs4/doc/genindex.html', 'title': 'General Index', 'accesskey': ['I']}

# %%
# Extrair o link
print(links[0]["href"])
# Out:
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/genindex.html

# %%
# Extrair todos os links da página
for link in links:
    print(link["href"])
# Out:
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/genindex.html
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/py-modindex.html
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#module-bs4
# http://www.crummy.com/software/BeautifulSoup/
# http://www.crummy.com/software/BeautifulSoup/bs3/documentation.html
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#porting-code-to-bs4
# https://www.crummy.com/software/BeautifulSoup/bs4/doc.zh/
# http://kondou.com/BS4/
# https://www.crummy.com/software/BeautifulSoup/bs4/doc.ko/
# https://www.crummy.com/software/BeautifulSoup/bs4/doc.ptbr
# https://www.crummy.com/software/BeautifulSoup/bs4/doc.ru/
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#getting-help
# https://groups.google.com/forum/?fromgroups#!forum/beautifulsoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#diagnose
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#quick-start
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-beautiful-soup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# http://www.crummy.com/software/BeautifulSoup/bs3/documentation.html
# http://www.crummy.com/software/BeautifulSoup/download/4.x/
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-a-parser
# http://lxml.de/
# http://code.google.com/p/html5lib/
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#differences-between-parsers
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#making-the-soup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id15
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kinds-of-objects
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Comment
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag.name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag.attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#multi-valued-attributes
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#replace-with
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#modifying-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#special-strings
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Comment
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Comment
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Comment
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Comment
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#for-html-documents
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Stylesheet
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Script
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Template
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#for-xml-documents
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Comment
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Declaration
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.w3.org/TR/REC-xml/#sec-prolog-dtd
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Doctype
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.w3.org/TR/REC-xml/#dt-doctype
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.CData
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.w3.org/TR/REC-xml/#sec-cdata-sect
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.ProcessingInstruction
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.w3.org/TR/REC-xml/#sec-pi
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#going-down
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-using-tag-names
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#contents-and-children
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#modifying-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#descendants
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#string
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#strings-and-stripped-strings
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#going-up
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parent
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parents
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#going-sideways
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#next-sibling-and-previous-sibling
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#next-siblings-and-previous-siblings
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#going-back-and-forth
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#next-element-and-previous-element
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#next-elements-and-previous-elements
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kinds-of-filters
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-string
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-regular-expression
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-list
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#true
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-function
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#recursive
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#limit
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kinds-of-filters
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-name-argument
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kinds-of-filters
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-string
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-regular-expression
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-list
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-function
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-value-true
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-keyword-arguments
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-string
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-regular-expression
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-list
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-function
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-value-true
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-by-css-class
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#multivalue
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-string-argument
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-string
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-regular-expression
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-list
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-function
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-value-true
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-limit-argument
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-recursive-argument
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#calling-a-tag-is-like-calling-find-all
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#recursive
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-using-tag-names
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-parents-and-find-parent
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#limit
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parent
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parents
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-next-siblings-and-find-next-sibling
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#limit
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#sibling-generators
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-previous-siblings-and-find-previous-sibling
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#limit
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#sibling-generators
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all-next-and-find-next
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#limit
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#element-generators
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all-previous-and-find-previous
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#limit
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#element-generators
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#css-selectors-through-the-css-property
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://facelessuser.github.io/soupsieve/
# https://facelessuser.github.io/soupsieve/selectors/
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#advanced-soup-sieve-features
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://facelessuser.github.io/soupsieve/
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#namespaces-in-css-selectors
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#history-of-css-selector-support
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#modifying-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#changing-tag-names-and-attributes
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag.attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#modifying-string
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#append
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#extend
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigablestring-and-new-tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#insert
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#insert-before-and-insert-after
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#clear
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#extract
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#decompose
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#replace-with
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#wrap
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#unwrap
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#smooth
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#output
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#pretty-printing
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#non-pretty-printing
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#encodings
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#output-formatters
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#formatter-objects
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.HTMLFormatter
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.XMLFormatter
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#writing-your-own-formatter
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.HTMLFormatter
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.XMLFormatter
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.CData
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#get-text
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#string-generators
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#specifying-the-parser-to-use
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-a-parser
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#differences-between-parsers
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#encodings
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#unicode-dammit
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#output-encoding
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#unicode-dammit
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#smart-quotes
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#inconsistent-encodings
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#line-numbers
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#comparing-objects-for-equality
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#copying-beautiful-soup-objects
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#advanced-parser-customization
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parsing-only-part-of-a-document
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.SoupStrainer
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.SoupStrainer
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.SoupStrainer
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.SoupStrainer
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kwargs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.SoupStrainer
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.SoupStrainer
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.SoupStrainer
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#customizing-multi-valued-attributes
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#handling-duplicate-attributes
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#instantiating-custom-subclasses
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#troubleshooting
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#diagnose
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#errors-when-parsing-a-document
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-a-parser
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parser-installation
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parser-installation
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#version-mismatch-problems
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parsing-xml
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parser-installation
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#other-parser-problems
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#differences-between-parsers
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# http://www.w3.org/TR/html5/syntax.html#syntax
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parsing-xml
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#miscellaneous
# http://wiki.python.org/moin/PrintFails
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#improving-performance
# http://lxml.de/
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parser-installation
# http://pypi.python.org/pypi/cchardet/
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parsing-only-part-of-a-document
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#translating-this-documentation
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id16
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# http://www.crummy.com/software/BeautifulSoup/bs3/download/3.x/BeautifulSoup-3.2.0.tar.gz
# http://www.crummy.com/software/BeautifulSoup/bs3/documentation.html
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#porting-code-to-bs4
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# http://www.python.org/dev/peps/pep-0008/
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#you-need-a-parser
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-a-parser
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#method-names
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#generators
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#string-generators
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#xml
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#entities
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#unicode-dammit
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#output-formatters
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id17
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#string
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#multi-valued-attributes
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#string
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id11
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#getting-help
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#quick-start
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-beautiful-soup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-a-parser
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#making-the-soup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kinds-of-objects
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag.name
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Tag.attrs
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.NavigableString
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#special-strings
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Comment
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#for-html-documents
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Stylesheet
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Script
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Template
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#for-xml-documents
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Declaration
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.Doctype
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.CData
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.ProcessingInstruction
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#going-down
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-using-tag-names
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#contents-and-children
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#descendants
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#string
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#strings-and-stripped-strings
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#going-up
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parent
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parents
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#going-sideways
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#next-sibling-and-previous-sibling
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#next-siblings-and-previous-siblings
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#going-back-and-forth
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#next-element-and-previous-element
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#next-elements-and-previous-elements
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kinds-of-filters
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-string
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-regular-expression
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-list
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#true
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-function
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-name-argument
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-keyword-arguments
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-by-css-class
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-string-argument
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-limit-argument
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-recursive-argument
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#calling-a-tag-is-like-calling-find-all
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-parents-and-find-parent
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-next-siblings-and-find-next-sibling
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-previous-siblings-and-find-previous-sibling
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all-next-and-find-next
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all-previous-and-find-previous
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#css-selectors-through-the-css-property
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#advanced-soup-sieve-features
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#namespaces-in-css-selectors
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#history-of-css-selector-support
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#modifying-the-tree
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#changing-tag-names-and-attributes
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#modifying-string
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#append
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#extend
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigablestring-and-new-tag
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#insert
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#insert-before-and-insert-after
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#clear
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#extract
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#decompose
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#replace-with
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#wrap
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#unwrap
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#smooth
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#output
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#pretty-printing
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#non-pretty-printing
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#output-formatters
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#formatter-objects
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.HTMLFormatter
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.XMLFormatter
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#writing-your-own-formatter
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#get-text
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#specifying-the-parser-to-use
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#differences-between-parsers
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#encodings
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#output-encoding
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#unicode-dammit
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#smart-quotes
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#inconsistent-encodings
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#line-numbers
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#comparing-objects-for-equality
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#copying-beautiful-soup-objects
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#advanced-parser-customization
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parsing-only-part-of-a-document
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.SoupStrainer
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#customizing-multi-valued-attributes
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#handling-duplicate-attributes
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#instantiating-custom-subclasses
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#troubleshooting
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#diagnose
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#errors-when-parsing-a-document
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#version-mismatch-problems
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parsing-xml
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#other-parser-problems
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#miscellaneous
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#improving-performance
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#translating-this-documentation
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id16
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#porting-code-to-bs4
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#you-need-a-parser
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#method-names
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#generators
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#xml
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#entities
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#id17
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/_sources/index.rst.txt
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/genindex.html
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/py-modindex.html
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/
# https://www.sphinx-doc.org/

# %% [markdown]
# #### Encontrando elementos com várias regras

# %%
elementos_navegacao = soup.find_all(["h1", "h2", "h3"])
print(elementos_navegacao)
# Out:
# [<h3>Navigation</h3>, <h1>Beautiful Soup Documentation<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#module-bs4" title="Permalink to this heading">¶</a></h1>, <h2>Getting help<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#getting-help" title="Permalink to this heading">¶</a></h2>, <h1>Quick Start<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#quick-start" title="Permalink to this heading">¶</a></h1>, <h1>Installing Beautiful Soup<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-beautiful-soup" title="Permalink to this heading">¶</a></h1>, <h2>Installing a parser<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-a-parser" title="Permalink to this heading">¶</a></h2>, <h1>Making the soup<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#making-the-soup" title="Permalink to this heading">¶</a></h1>, <h1>Kinds of objects<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kinds-of-objects" title="Permalink to this heading">¶</a></h1>, <h2>Multi-valued attributes<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#multi-valued-attributes" title="Permalink to this heading">¶</a></h2>, <h2>Special strings<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#special-strings" title="Permalink to this heading">¶</a></h2>, <h3>For HTML documents<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#for-html-documents" title="Permalink to this heading">¶</a></h3>, <h3>For XML documents<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#for-xml-documents" title="Permalink to this heading">¶</a></h3>, <h1>Navigating the tree<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-the-tree" title="Permalink to this heading">¶</a></h1>, <h2>Going down<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#going-down" title="Permalink to this heading">¶</a></h2>, <h3>Navigating using tag names<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#navigating-using-tag-names" title="Permalink to this heading">¶</a></h3>, <h3><code class="docutils literal notranslate"><span class="pre">.contents</span></code> and <code class="docutils literal notranslate"><span class="pre">.children</span></code><a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#contents-and-children" title="Permalink to this heading">¶</a></h3>, <h3><code class="docutils literal notranslate"><span class="pre">.descendants</span></code><a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#descendants" title="Permalink to this heading">¶</a></h3>, <h3><code class="docutils literal notranslate"><span class="pre">.string</span></code><a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#string" title="Permalink to this heading">¶</a></h3>, <h3><code class="docutils literal notranslate"><span class="pre">.strings</span></code> and <code class="docutils literal notranslate"><span class="pre">stripped_strings</span></code><a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#strings-and-stripped-strings" title="Permalink to this heading">¶</a></h3>, <h2>Going up<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#going-up" title="Permalink to this heading">¶</a></h2>, <h3><code class="docutils literal notranslate"><span class="pre">.parent</span></code><a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parent" title="Permalink to this heading">¶</a></h3>, <h3><code class="docutils literal notranslate"><span class="pre">.parents</span></code><a class=" ...

# %% [markdown]
# #### Outras regras de find()
# - por classe (class_)
# - por id (id)
# - por atributos (role, href, src, etc)
# - por texto (string)
# - por pedaços de texto

# %%
imagem = soup.find("img")
print(imagem)
print(imagem["src"])
# Out:
# <img alt='"The Fish-Footman began by producing from under his arm a great letter, nearly as large as himself."' class="align-right" src="./Beautiful Soup Documentation_files/6.1.jpg"/>
# ./Beautiful Soup Documentation_files/6.1.jpg

# %%
# Buscar por classe
headerlink = soup.find(class_="headerlink")
print(headerlink)
# Out:
# <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#module-bs4" title="Permalink to this heading">¶</a>

# %%
# Buscar por id
qs = soup.find(id="quick-start")
print(qs.prettify())
# Out:
# <section id="quick-start">
#  <h1>
#   Quick Start
#   <a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#quick-start" title="Permalink to this heading">
#    ¶
#   </a>
#  </h1>
#  <p>
#   Here’s an HTML document I’ll be using as an example throughout this
# document. It’s part of a story from
#   <cite>
#    Alice in Wonderland
#   </cite>
#   :
#  </p>
#  <div bis_skin_checked="1" class="highlight-default notranslate">
#   <div bis_skin_checked="1" class="highlight">
#    <pre><span></span><span class="n">html_doc</span> <span class="o">=</span> <span class="s2">"""&lt;html&gt;&lt;head&gt;&lt;title&gt;The Dormouse's story&lt;/title&gt;&lt;/head&gt;</span>
# <span class="s2">&lt;body&gt;</span>
# <span class="s2">&lt;p class="title"&gt;&lt;b&gt;The Dormouse's story&lt;/b&gt;&lt;/p&gt;</span>
#
# <span class="s2">&lt;p class="story"&gt;Once upon a time there were three little sisters; and their names were</span>
# <span class="s2">&lt;a href="http://example.com/elsie" class="sister" id="link1"&gt;Elsie&lt;/a&gt;,</span>
# <span class="s2">&lt;a href="http://example.com/lacie" class="sister" id="link2"&gt;Lacie&lt;/a&gt; and</span>
# <span class="s2">&lt;a href="http://example.com/tillie" class="sister" id="link3"&gt;Tillie&lt;/a&gt;;</span>
# <span class="s2">and they lived at the bottom of a well.&lt;/p&gt;</span>
#
# <span class="s2">&lt;p class="story"&gt;...&lt;/p&gt;</span>
# <span class="s2">"""</span>
# </pre>
#   </div>
#  </div>
#  <p>
#   Running the “three sisters” document through Beautiful Soup gives us a
#   <a class="reference internal" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#bs4.BeautifulSoup" title="bs4.BeautifulSoup">
#    <code class="xref py py-class docutils literal notranslate">
#     <span class="pre">
#      BeautifulSoup
#     </span>
#    </code>
#   </a>
#   object, which represents the document as a nested
# data structure:
#  </p>
#  <div bis_skin_checked="1" class="highlight-default notranslate">
#   <div bis_skin_checked="1" class="highlight">
#    <pre><span></span><span class="kn">from</span> <span class="nn">bs4</span> <span class="kn">import</span> <span class="n">BeautifulSoup</span>
# <span class="n">soup</span> <span class="o">=</span> <span class="n">BeautifulSoup</span><span class="p">(</span><span class="n">html_doc</span><span class="p">,</span> <span class="s1">'html.parser'</span><span class="p">)</span>
#
# <span class="nb">print</span><span class="p">(</span><span class="n">soup</span><span class="o">.</span><span class="n">prettify</span><span class="p">())</span>
# <span class="c1"># &lt;html&gt;</span>
# <span class="c1">#  &lt;head&gt;</span>
# <span class="c1">#   &lt;title&gt;</span>
# <span class="c1">#    The Dormouse's story</span>
# <span class="c1">#   &lt;/title&gt;</span>
# <span class="c1">#  &lt;/head&gt;</span>
# <span class="c1">#  &lt;body&gt;</span>
# <span class="c1">#   &lt;p class="title"&gt;</span>
# <span class="c1">#    &lt;b&gt;</span>
# <span class="c1">#     The Dormouse's story</span>
# <span class="c1">#    &lt;/b&gt;</span>
# <span class="c1">#   &lt;/p&gt;</span>
# <span class="c1">#   &lt;p class="story"&gt;</span>
# <span class="c1">#    Once upon a time there were three little sisters; and their names were</span>
# <span class="c1">#    &lt;a class="sister" href="http://example.com/elsie" id="link1"&gt;</span>
# <span class="c1">#     Elsie</span>
# <span class="c1">#    &lt;/a&gt;</span>
# <span class="c1">#    ,</span>
# <span class="c1">#    &lt;a class="sister" href="http://example.com/lacie" id="link2"&gt;</span>
# <span class="c1">#     Lacie</span>
# <span class="c1">#    &lt;/a&gt;</span>
# <span class="c1">#    and</span>
# <span class="c1">#    &lt;a class="sister" href="http://example.com/tillie" id="link3"&gt;</span>
# <span class="c1">#     Tillie</span>
# <span class="c1">#    &lt;/a&gt;</span>
# <span class="c1">#    ; and they lived at the bottom of a well.</span>
# <span class="c1">#   &lt;/p&gt;</span>
# <span class="c1">#   &lt;p class="story"&gt;</span>
# <span class="c1">#    ...</span>
# <span class="c1">#   &lt;/p&gt;</span>
# <span class="c1">#  &lt;/body&gt;</span>
# <span class="c1"># &lt;/html&gt;</span>
# </pre>
#   </div>
#  </div>
#  <p>
#   Here are some simple ways to navigate that data structure:
#  </p>
#  <div bis_skin_checked="1" class="highlight-default notranslate">
#   <div bis_skin_checked="1" class="highlight">
#    <pre><span></span><span class="n">soup</span><span class="o">.</span><span class="n">title</span>
# <span class="c1"># &lt;title&gt;The Dormouse's story&lt;/title&gt;</span>
#
# <span class="n">soup</span><span class="o">.</span><span class="n">title</span><span class="o">.</span><span class="n">name</span>
# <span class="c1"># u'title'</span>
#
# <span class="n">soup</span><span class="o">.</span><span class="n">title</span><span class="o">.</span><span class="n">string</span>
# <span class="c1"># u'The Dormouse's story'</span>
#
# <span class="n">soup</span><span class="o">.</span><span class="n">title</span><span class="o">.</span><span class="n">parent</span><span class="o">.</span><span class="n">name</span>
# <span class="c1"># u'head'</span>
#
# <span class="n">soup</span><span class="o">.</span><span class="n">p</span>
# <span class="c1"># &lt;p class="title"&gt;&lt;b&gt;The Dormouse's story&lt;/b&gt;&lt;/p&gt;</span>
#
# <span class="n">soup</span><span class="o">.</span><span class="n">p</span><span class="p">[</span><span class="s1">'class'</span><span class="p">]</span>
# <span class="c1"># u'title'</span>
#
# <span class="n">soup</span><span class="o">.</span><span class="n">a</span>
# <span class="c1"># &lt;a class="sister" href="http://example.com/elsie" id="link1"&gt;Elsie&lt;/a&gt;</span>
#
# <span class="n">soup</span><span class="o">.</span><span class="n">find_all</span><span class="p">(</span><span class="s1">'a'</span><span class="p">)</span>
# <span class="c1"># [&lt;a class="sister" href="http://example.com/elsie" id="link1"&gt;Elsie&lt;/a&gt;,</span>
# <span class="c1">#  &lt;a class="sister" href="http://example.com/lacie" id="link2"&gt;Lacie&lt;/a&gt;,</span>
# <span class="c1">#  &lt;a class="sister" href="http://example.com/tillie" id="link3"&gt;Tillie&lt;/a&gt;]</span>
#
# <span class="n">soup</span><span class="o">.</span><span class="n">find</span><span class="p">(</span><span class="nb">id</span><span class="o">=</span><span class="s2">"link3"</span><span class="p">)</span>
# <span class="c1"># &lt;a class="sister" href="http://example.com/tillie" id="link3"&gt;Tillie&lt;/a&gt;</span>
# </pre>
#   </div>
#  </div>
#  <p>
#   One common task is extracting all the URLs found within a page’s &lt;a&gt; tags:
#  </p>
#  <div bis_skin_checked="1" class="highlight-default notranslate">
#   <div bis_skin_checked="1" class="highlight">
#    <pre><span></span><span class="k">for</span> <span class="n">link</span> <span class="ow">in</span> <span class="n">soup</span><span class="o">.</span><span class="n">find_all</span><span class="p">(</span><span class="s1">'a'</span><span class="p">):</span>
#     <span class="nb">print</span><span class="p">(</span><span class="n">link</span><span class="o">.</span><span class="n">get</span><span class="p">(</span><span class="s1">'href'</span><span class="p">))</span>
# <span class="c1"># http://example.com/elsie</span>
# <span class="c1"># http://example.com/lacie</span>
# <span class="c1"># http://example.com/tillie</span>
# </pre>
#   </div>
#  </div>
#  <p>
#   Another common task is extracting all the text from a page:
#  </p>
#  <div bis_skin_checked="1" class="highlight-default notranslate">
#   <div bis_skin_checked="1" class="highlight">
#    <pre><span></span><span class="nb">print</span><span class="p">(</span><span class="n">soup</span><span class="o">.</span><span class="n">get_text</span><span class="p">())</span>
# <span class="c1"># The Dormouse's story</span>
# <span class="c1">#</span>
# <span class="c1"># The Dormouse's story</span>
# <span class="c1">#</span>
# <span class="c1"># Once upon a time there were three little sisters; and their names were</span>
# <span class="c1"># Elsie,</span>
# <span class="c1"># Lacie and</span>
# <span class="c1"># Tillie;</span>
# <span class="c1"># and they lived at the bottom of a well.</span>
# <span class="c1">#</span>
# <span class="c1"># ...</span>
# </pre>
#   </div>
#  </div>
#  <p>
#   Does this look like what you need? If so, read on.
#  </p>
# </section>

# %%
# Buscar com múltiplos filtros
elemento = soup.find(id="#", role="#")

# %% [markdown]
# Obs.: Quando o parâmetro tiver caracteres especiais, passar em forma de dicionário:

# %%
logo = soup.find("img", {"data-ll-status": "loaded", "class": "custom-logo"})

# %% [markdown]
# #### Busca por texto

# %%
# Texto é igual
instalacao = soup.find(string="Installing Beautiful Soup")
print(instalacao)
# Out:
# Installing Beautiful Soup

# %%
# Texto contém
import re  # Expressões regulares

textos = soup.find_all(string=re.compile("Installing"))
print(textos)
# Out:
# ['Installing Beautiful Soup', 'Installing a parser', 'Installing a parser', '# I noticed that html5lib is not installed. Installing it may help.', 'Installing a parser', 'Installing a parser', 'Installing Beautiful Soup', 'Installing a parser']

# %% [markdown]
# #### Parent e Contents

# %%
# Parent retorna o elemento pai (acima na hierarquia)
parent = textos[0].parent
print(parent)
# Out:
# <h1>Installing Beautiful Soup<a class="headerlink" href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-beautiful-soup" title="Permalink to this heading">¶</a></h1>

# %%
# Contents retorna os elementos filhos (abaixo na hierarquia)
parent.contents[0]
# Out:
# 'Installing Beautiful Soup'
